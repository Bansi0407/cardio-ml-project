# %% [markdown]
# # Name : Bansi Ajagia
# # **Subject** : Machine Learning
# # **Project** : Cardiovascular Disease Prediction System
#
# ---
#
# # Task 8 — Frontend Design

# %% [markdown]
# ## 🎨 UI Design Plan
#
# The frontend uses **Streamlit** with a clean medical-inspired dark theme.
#
# ### Layout:
# - Sidebar for navigation
# - Columns for input fields (3-column grid)
# - Cards for metric display
# - Color-coded result blocks (red = risk, green = safe)

# %%
# Name : Bansi Ajagia
# Subject : Machine Learning
# Project : Cardiovascular Disease Prediction System

# This notebook documents the UI structure
ui_sections = {
    'Sidebar': ['Logo', 'Navigation radio', 'Student info'],
    'Home': ['Project title', 'About text', 'Dataset info table', 'Status badges'],
    'Data Analysis': ['Quick stats (4 metrics)', 'Tabs: Raw Data | Distributions | Heatmap'],
    'Train Model': ['Train button', 'Metrics table', 'Bar chart', 'Confusion matrix image'],
    'Prediction': ['3-column input form', 'Predict button', 'Risk result card'],
}
for section, items in ui_sections.items():
    print(f'\n📌 {section}:')
    for item in items:
        print(f'   • {item}')
# Out:
# 📌 Sidebar:
#    • Logo
#    • Navigation radio
#    • Student info
#
# 📌 Home:
#    • Project title
#    • About text
#    • Dataset info table
#    • Status badges
#
# 📌 Data Analysis:
#    • Quick stats (4 metrics)
#    • Tabs: Raw Data | Distributions | Heatmap
#
# 📌 Train Model:
#    • Train button
#    • Metrics table
#    • Bar chart
#    • Confusion matrix image
#
# 📌 Prediction:
#    • 3-column input form
#    • Predict button
#    • Risk result card

# %% [markdown]
# ## 📝 Input Fields for Prediction
#
# | Field | Widget | Range |
# |---|---|---|
# | Age | Slider | 10–100 |
# | Gender | Selectbox | Male/Female |
# | Height | Slider | 100–220 cm |
# | Weight | Slider | 30–200 kg |
# | Systolic BP | Slider | 60–250 |
# | Diastolic BP | Slider | 40–200 |
# | Cholesterol | Selectbox | Normal/Above/Well Above |
# | Glucose | Selectbox | Normal/Above/Well Above |
# | Smoking | Selectbox | Yes/No |
# | Alcohol | Selectbox | Yes/No |
# | Physical Active | Selectbox | Yes/No |

# %% [markdown]
# ## 🎨 Custom CSS Highlights
#
# ```css
# /* Metric card */
# .metric-card { background: linear-gradient(135deg, #1a1a2e, #16213e); border-radius: 12px; }
#
# /* High risk result */
# .risk-high { background: linear-gradient(135deg, #742020, #c0392b); }
#
# /* Safe result */
# .risk-none { background: linear-gradient(135deg, #1a472a, #27ae60); }
# ```
